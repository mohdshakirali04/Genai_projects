# %% [markdown]
# *_1. User Login Check_*

# %%
# Stored login credentials
stored_username = "admin"
stored_password = "1234"

# Taking input from user
username = input("Enter username: ")
password = input("Enter password: ")

# Checking login details
if username == stored_username and password == stored_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username:  admin
# Enter password:  1234
# Login Successful

# %% [markdown]
# *_2. Pass / Fail Analyzer_*

# %%
# List of student marks
marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

# Checking each student's result
for m in marks:
    if m >= 50:
        pass_count += 1
    else:
        fail_count += 1

# Displaying results
print("Total Students:", len(marks))
print("Pass Students:", pass_count)
print("Fail Students:", fail_count)
# Out:
# Total Students: 5
# Pass Students: 3
# Fail Students: 2

# %% [markdown]
# *_3. Simple Data Cleaner_*

# %%
# Raw list of names
names = [" Alice ", "bob", " CHARLIE "]

# Step 1: Remove extra spaces
no_space_names = []
for name in names:
    no_space_names.append(name.strip())

print("After removing spaces:", no_space_names)

# Step 2: Convert names to lowercase
cleaned_names = []
for name in no_space_names:
    cleaned_names.append(name.lower())

# Step 3: Print cleaned list
print("Cleaned Names:", cleaned_names)
# Out:
# After removing spaces: ['Alice', 'bob', 'CHARLIE']
# Cleaned Names: ['alice', 'bob', 'charlie']

# %% [markdown]
# *_4. Message Length Analyzer_*

# %%
# List of messages
messages = ["Hi", "Welcome to the platform", "OK"]

# Checking message lengths
for msg in messages:
    length = len(msg)
    print("Message:", msg)
    print("Length:", length)

    if length > 10:
        print("Status: Long Message")
    else:
        print("Status: Short Message")

    print("--------------------")
# Out:
# Message: Hi
# Length: 2
# Status: Short Message
# --------------------
# Message: Welcome to the platform
# Length: 23
# Status: Long Message
# --------------------
# Message: OK
# Length: 2
# Status: Short Message
# --------------------

# %% [markdown]
# *_5. Error Message Detector_*

# %%
# System log entries
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = 0

# Counting ERROR entries
for log in logs:
    if log == "ERROR":
        error_count += 1

# Displaying error count
print("Total ERROR entries:", error_count)
# Out:
# Total ERROR entries: 2
